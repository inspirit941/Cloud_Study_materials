# %%
import glob

# %%
glob.glob("*.srt")
# Out:
# ['1.3_ Building Container Images.srt']

# %%
with open(glob.glob("*.srt")[0], 'r') as f:
    text = f.readlines()
    
result = []
for t in text:
    if not t[0].isdigit() and t != "\n":
        result.append(t)
result
# Out:
# ['컨테이너 이미지를 구성하는 요소에는 어떤 것들이 있는지, 어떻게 빌드되는지를 살펴보겠습니다.\n',
#  '이 그림은 실행 중인 컨테이너가 어떻게 만들어지는지를 보여주고 있습니다.\n',
#  '도커 파일은 해당 이미지를 빌드하기 위한 일종의 청사진으로,\n',
#  '원하는 형태의 이미지를 구성하기 위한 개요를 제공합니다.\n',
#  '그 후, 도커가 도커 파일을 토대로 이미지를 빌드합니다.\n',
#  '컨테이너와 이미지의 차이점은 매우 중요한 개념입니다.\n',
#  '둘은 완전히 다른 개념을 지칭하는 용어이기 때문입니다.\n',
#  '이미지는 애플리케이션이 실행되기 위해 필요한\n',
#  '소스코드, 라이브러리, 의존 객체 등을 포함하는 불변 파일입니다.\n',
#  '불변 파일이라는 건, 읽기 전용 파일이라는 뜻입니다. 즉 이미지를 변경하면, 새로운 이미지를 생성하게 됩니다.\n',
#  '말하자면, 이미지는 컨테이너를 구성할 템플릿이자 청사진입니다.\n',
#  '컨테이너의 스냅샷이라고도 볼 수 있습니다.\n',
#  '따라서, 컨테이너는 실행 중인 이미지를 의미합니다. 이미지 자체는 읽기 전용인 불변 파일이므로,\n',
#  '기록 가능한 레이어가 이미지의 최상위에 배치되어 컨테이너가 이미지 파일을 실행할 수 있게 합니다.\n',
#  '객체지향 프로그래밍 개념으로 비유하자면 \n',
#  '이미지는 일종의 클래스이며,\n',
#  '컨테이너는 그 클래스를 토대로 생성된 인스턴스입니다.\n',
#  '이 그림에서 알 수 있듯, 처음에는 이미지에 무엇을 포함할 것인지\n',
#  '도커 파일에 정의한 후, 정의한 도커 파일을 사용해서 이미지를 빌드합니다.\n',
#  '그 후 빌드된 이미지를 실행하면, 컨테이너가 생성됩니다.\n',
#  '이것이 컨테이너 생성을 위한 기본 절차입니다.\n',
#  '도커는 도커 파일에 정의된 내용을 토대로 이미지를 자동으로 빌드해 줍니다.\n',
# ...
